# %% [markdown]
# #Network

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 25 Jan 2022 13:34:10 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request
fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# #Object

# %%
class PartyAnimal:
    x = 0
    name = ''
    def __init__(self, nam):
        self.name = nam
        print(self.name,'constructed')
    def party(self):
        self.x = self.x + 1
        print(self.name,'party count',self.x)

q = PartyAnimal('Quincy')
m = PartyAnimal('Miya')

q.party()
m.party()
q.party()
# Out:
# Quincy constructed
# Miya constructed
# Quincy party count 1
# Miya party count 1
# Quincy party count 2

# %% [markdown]
# #Python Project 1 - arithmetic_arranger

# %%
def arithmetic_arranger(problems):
  first_line = []
  second_line = []
  third_line = []
  for word in problems:
    if "+" in word:
      number = word.replace(" ","").split("+")
      res = max(number, key = len)
      r_just = len(res)
      
      first_line.append([number[0].rjust(r_just+2)])
      try:
        second_line.append(number[1].rjust(r_just+1))
      except AttributeError:
        print(number[1].rjust(r_just+1))
        second_line.append(number[1].rjust(r_just+1))
      second_line.insert(0,"+")
      print(second_line)
      second_line  = "".join(second_line)
    
      for i in range(r_just+2):
        third_line.append('_')
      third_line  = "".join(third_line)
    
    # first_line  = "    ".join(first_line)
    # second_line = "    ".join(second_line)
  arranged_problems = first_line+"\n"+second_line+"\n"+third_line

  return arranged_problems
# print(arithmetic_arranger(["32 + 698"]))
print(arithmetic_arranger(["32 + 698", "3801 - 2", "45 + 43", "123 + 49"]))
# Out:
# ['+', ' 698']
#  43
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-b5cb5ec17efc> in arithmetic_arranger(problems)
#      12       try:
# ---> 13         second_line.append(number[1].rjust(r_just+1))
#      14       except AttributeError:
#
# AttributeError: 'str' object has no attribute 'append'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-b5cb5ec17efc> in <module>()
#      29   return arranged_problems
#      30 # print(arithmetic_arranger(["32 + 698"]))
# ---> 31 print(arithmetic_arranger(["32 + 698", "3801 - 2", "45 + 43", "123 + 49"]))
#
# <ipython-input-73-b5cb5ec17efc> in arithmetic_arranger(problems)
#      14       except AttributeError:
#      15         print(number[1].rjust(r_just+1))
# ...

# %%
kacang = [1,2]
kacang.insert(0,12)
kacang
# Out:
# [12, 1, 2]
