# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 25 Jan 2022 13:34:10 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request
fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
uname = "afifhrz"
# !git config --global user.email 'ahmadafif.hariz@gmail.com'
# !git config --global user.name 'afifhrz'

#Make a clone of github REPO
# !git clone https://github.com/afifhrz/python_for_everybody_FCC

#Copy file from either google drive after mounting using file browser
# !cp /content/drive/MyDrive/Colab Notebooks/MyProject/networking_in_python.ipynb /content/<REPO_NAME>
# Out:
# Cloning into 'python_for_everybody_FCC'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/MyProject/networking_in_python.ipynb /content/python_for_everybody_FCC
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/MyProject/networking_in_python.ipynb': No such file or directory

# %%
 # !git add networking_in_python.ipynb
 # !git commit -m 'commit this file by code'  # commit in Colab
 # !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
